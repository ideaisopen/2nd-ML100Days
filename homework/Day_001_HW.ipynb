# %%
"""
問題一
   我找的是Kaggle中的Trending YouTube Video Statistics
   是由Youtube官方所提供的資料，我主要選擇他的原因是因為自己也喜歡看Youtube因此想要多了解相關的資料
   這份資料約十個國家的資料，裡面的欄位有影片的ID、上線日期、標題、tag、觀看數、按讚數、不喜歡數、縮圖、以及留言
   我預期可以透過留言、標題以及Tag和影片說明來分類怎麼樣的影片受歡迎的原因
   

問題二
   如何提升業績：每個顧客在想叫車時都可以叫得道並被服務的很好
   因此在每個區域都有足夠多的車手可以服務到顧客，他的媒合度可以到達一個平衡點，業機會最好。
   
   核心問題：一個區域有多少顧客，需要搭配多少車手
   資料從何而來：應該要有一個叫車的APP作為收集數據的來源。透過APP裡的GPS定位資訊、每個地區每天的接送的需求、頻次、人數、目的地在哪裡作為主要資料
   蒐集而來的資料型態為何：csv? json?
   如何驗證：
   1. 將服務區域分區，並分析區域中客戶數量和車手數量的關係，驗證是否是車手與客戶數量平衡會帶來最多業績?
   2. 如果是，進一步需要分析車手與客戶的平衡點在哪，即多少客戶附近應該要有多少車手?
   3. 如何透過分配客戶的方式來平衡做到最大化的效益，即車手跑最短距離接到客戶、客戶等待時間最短以及總體服務到最多客戶
      
"""

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
def mean_squared_error(y,yp):
    mse = MSE = np.sum((yp-y)**2)/len(y)
    return MSE

# %%
w = 3
b = 0.5

x_lin = np.linspace(0, 100, 101)

y = (x_lin + np.random.randn(101) * 5) * w + b

plt.plot(x_lin, y, 'b.', label = 'data points')
plt.title("Assume we have data points")
plt.legend(loc = 2)
plt.show()

# %%
y_hat = x_lin * w + b
plt.plot(x_lin, y, 'b.', label = 'data')
plt.plot(x_lin, y_hat, 'r-', label = 'prediction')
plt.title("Assume we have data points (And the prediction)")
plt.legend(loc = 2)
plt.show()

# %%
def mean_absolute_error(y, yp):
    """
    計算 MAE
    Args:
        - y: 實際值
        - yp: 預測值
    Return:
        - mae: MAE
    """
    mae = MAE = sum(abs(y - yp)) / len(y)
    return mae

MAE = mean_absolute_error(y, y_hat)
print("The Mean absolute error is %.3f" % (MAE))
# Out:
# The Mean absolute error is 11.849

# %%
MSE=mean_squared_error(y,y_hat)
print (MSE)
# Out:
# 219.92405027137406
